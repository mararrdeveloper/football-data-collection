# %%
import pandas as pd
import numpy as np
from helpers import calibrate_train_clfs, load_data, get_baseline, print_results, run_clf

#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
keep_columns =  ['IsTraining','FTR', 'Div',  
    'away_away_team_corners_against', 'away_away_team_corners_for',	'away_away_team_goals_against',	'away_away_team_goals_for',	
    'away_away_team_possession',	'away_away_team_shotsoff_against',	'away_away_team_shotsoff_for',	'away_away_team_shotson_against',
    	'away_away_team_shotson_for',	'away_direct_team_corners_against',	'away_direct_team_corners_for',	'away_direct_team_goals_against',
        'away_direct_team_goals_for',	'away_direct_team_possession',	'away_direct_team_shotsoff_against',	'away_direct_team_shotsoff_for',
        'away_direct_team_shotson_against',	'away_direct_team_shotson_for',	'home_direct_team_corners_against',	'home_direct_team_corners_for',	
        'home_direct_team_goals_against',	'home_direct_team_goals_for',	'home_direct_team_possession',	'home_direct_team_shotsoff_against',
        'home_direct_team_shotsoff_for',	'home_direct_team_shotson_against',	'home_direct_team_shotson_for',	
        'home_home_team_corners_against',	'home_home_team_corners_for',	'home_home_team_goals_against',	'home_home_team_goals_for',	
        'home_home_team_possession',	'home_home_team_shotsoff_against',	'home_home_team_shotsoff_for',	'home_home_team_shotson_against',
                 'home_home_team_shotson_for', 
]
 
drop_columns = ['Referee', 'Date', 'HomeTeam', 'AwayTeam',
    'B365H', 'B365D', 'B365A',                                       
    'AC', 'AF', 'AR', 'AS', 'AST', 'AY', 
    'BWA', 'BWD', 'BWH', 'Bb1X2', 'BbAH', 'BbAHh', 'BbAv<2.5', 'BbAv>2.5', 'BbAvA', 'BbAvAHA', 
    'BbAvAHH', 'BbAvD', 'BbAvH', 'BbMx<2.5', 'BbMx>2.5', 'BbMxA', 'BbMxAHA', 'BbMxAHH', 'BbMxD',
    'BbMxH', 'BbOU', 'FTAG', 
    'HC', 'HF', 'HR', 'HS', 'HST', 
    'HTAG', 'HTHG', 'HTR', 'HY', 'IWA', 'IWD', 'IWH', 
    'LBA', 'LBD', 'LBH', 'PSA', 'PSCA', 'PSCD', 'PSCH', 'PSD', 'PSH', 
    'VCA', 'VCD', 'VCH', 'WHA', 'WHD', 'WHH', 'GoalFirstHalf', 'SHHG', 'SHAG', 'GoalSecondHalf','FTR','BothToScore',
]

#
target_column = "FTR"
drop_columns.remove(target_column)
X,y = load_data(columns_to_drop=drop_columns, is_training=True, target_name=target_column)
# Out:
# KEEEP
# LENGTH1180

# %%
#x = load_boston()
df = pd.DataFrame(X)
df[target_column] = y
X = df.drop(target_column,1)   #Feature Matrix
y = df[target_column]          #Target Variable
print(df.iloc[0])

#Using Pearson Correlation
# Out:
# index                                      0
# FTHG                                       0
# away_away_1_team_corners_against           3
# away_away_1_team_corners_for               6
# away_away_1_team_goals_against             1
# away_away_1_team_goals_for                 6
# away_away_1_team_possession               63
# away_away_1_team_shotsoff_against          4
# away_away_1_team_shotsoff_for              3
# away_away_1_team_shotson_against           4
# away_away_1_team_shotson_for               9
# away_away_3_team_corners_against           5
# away_away_3_team_corners_for         7.33333
# away_away_3_team_goals_against       1.33333
# away_away_3_team_goals_for                 3
# away_away_3_team_possession          52.9167
# away_away_3_team_shotsoff_against    5.66667
# away_away_3_team_shotsoff_for        5.33333
# away_away_3_team_shotson_against     3.66667
# away_away_3_team_shotson_for         6.66667
# away_away_6_team_corners_against         4.5
# away_away_6_team_corners_for         7.16667
# away_away_6_team_goals_against       1.66667
# away_away_6_team_goals_for           2.16667
# away_away_6_team_possession          48.9167
# away_away_6_team_shotsoff_against    4.83333
# away_away_6_team_shotsoff_for        5.83333
# away_away_6_team_shotson_against           4
# away_away_6_team_shotson_for         6.16667
# away_direct_team_corners_against           0
#                                       ...
# home_direct_team_shotson_for               0
# home_home_1_team_corners_against           0
# home_home_1_team_corners_for               0
# home_home_1_team_goals_against             0
# home_home_1_team_goals_for                 0
# home_home_1_team_possession                0
# home_home_1_team_shotsoff_against          0
# home_home_1_team_shotsoff_for              0
# home_home_1_team_shotson_against           0
# home_home_1_team_shotson_for               0
# home_home_3_team_corners_against           0
# home_home_3_team_corners_for               0
# home_home_3_team_goals_against             0
# home_home_3_team_goals_for                 0
# home_home_3_team_possession                0
# home_home_3_team_shotsoff_against          0
# home_home_3_team_shotsoff_for              0
# home_home_3_team_shotson_against           0
# home_home_3_team_shotson_for               0
# home_home_6_team_corners_against           0
# home_home_6_team_corners_for               0
# home_home_6_team_goals_against             0
# home_home_6_team_goals_for                 0
# home_home_6_team_possession                0
# home_home_6_team_shotsoff_against          0
# home_home_6_team_shotsoff_for              0
# home_home_6_team_shotson_against           0
# home_home_6_team_shotson_for               0
# Div_E0                                     1
# FTR                                        A
# Name: 0, Length: 130, dtype: object

# %%
plt.figure(figsize=(20,20))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
cor_target = abs(cor[target_column])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\martin\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FTR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-b0e2eb9084d8> in <module>
# ----> 1 cor_target = abs(cor[target_column])
#       2 #Selecting highly correlated features
#       3 relevant_features = cor_target[cor_target>0.5]
#       4 relevant_features
#       5
#
# c:\users\martin\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# c:\users\martin\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# c:\users\martin\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# c:\users\martin\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\martin\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FTR'

# %%
print(df[["FTR","away_away_1_team_goals_against"]].corr())
